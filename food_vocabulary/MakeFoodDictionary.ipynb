# %%
from pinyin import get as get_pinyin
import translators
import json 
import time
import jieba

language = ''
language = '-vi'
target_lang = 'en'

chars = set()

# %%
# Open the file in read mode
word_dict = {}
MAX_COUNT = 10000
count = 0

with open('Foodlist.txt', 'r', encoding='utf-8') as file:
    next(file)
    # Iterate through each line in the file
    for line in file:
        line = line.strip()

        if not line:
            continue

        count += 1

        if count > MAX_COUNT:
            break
        
        # Split the line into four variables
        chinese, pinyin, english = line.split('\t')

        chars.update(list(chinese))

        # Do something with the variables, for example, print them
        # print(f"Chinese: {chinese}, Pinyin: {pinyin}, English: {english}")

        word_dict[chinese] = {'pinyin': get_pinyin(chinese), 'chinese': [], 'english': english}
        
        seg_list = list(jieba.cut(chinese, cut_all=False))

        if len(seg_list) == 1:
            seg_list = []

        for char in set((list(chinese)+seg_list)):
            if char not in word_dict:
                word_dict[char] = {'pinyin': get_pinyin(char), 'chinese': [chinese]}
            else:
                word_dict[char]['chinese'].append(chinese)

from deep_translator import GoogleTranslator

for i, word in enumerate(word_dict):
    if 'english' in word_dict[word]:
        print(f'Already has translation: {word_dict[word]["english"]}')
    else:
        english = GoogleTranslator(source='auto', target=target_lang).translate(word)  
        
        print(f'Translating to {target_lang} {i+1}/{len(word_dict)} {word} - {english}')

        word_dict[word]['english'] = english

        time.sleep(1)

food_pleco_data_file = f'food_pleco{language}.json'

with open(food_pleco_data_file, 'w', encoding='utf-8') as fwrite:
    json.dump(word_dict, fwrite, indent = 4, ensure_ascii=False)

print(f'Data file written {food_pleco_data_file}')
# Out:
# Already has translation: Chinese noodles
# Translating to en 2/411 面 - noodle
# Translating to en 3/411 条 - strip
# Already has translation: Chow mein
# Translating to en 5/411 炒 - saute
# Already has translation: Noodle soup
# Translating to en 7/411 汤 - Soup
# Already has translation: Zhajiangmian
# Translating to en 9/411 酱 - Sauce
# Translating to en 10/411 炸 - fry
# Already has translation: Lamian
# Translating to en 12/411 拉 - pull
# Already has translation: White Rice
# Translating to en 14/411 米 - rice
# Translating to en 15/411 饭 - meal
# Already has translation: Fried Rice
# Already has translation: Dongpo Braised Pork
# Translating to en 18/411 坡 - slope
# Translating to en 19/411 东 - East
# Translating to en 20/411 肉 - meat
# Already has translation: sweet and meetha
# Translating to en 22/411 咾 - Hey
# Translating to en 23/411 咕 - Goo
# Already has translation: Twice cooked pork
# Translating to en 25/411 回 - times
# Translating to en 26/411 锅 - pot
# ...

# %%
with open(f'food_pleco{language}.json', 'r', encoding='utf-8') as fread:
    word_dict = json.load(fread)

def pleco_make_bold(text):
    return f'\uEAB2{text}\uEAB3'

def pleco_make_italic(text):
    return f'\uEAB4{text}\uEAB5'

def pleco_make_link(text):
    return f'\uEAB8{text}\uEABB'

def pleco_make_newline():
    return f'\uEAB1'

pleco_import_file = f'FoodVocabularyPleco{language}.txt'
fpleco = open(pleco_import_file, 'w', encoding='utf-8')

fpleco.write(f'// Food Vocabulary{language}\n')

word_list = sorted(word_dict.keys(), key = lambda x: (len(x), x))

for word in word_list:
    data = word_dict[word]

    if data['chinese']:
        fpleco.write(f"{word}\t{word_dict[word]['pinyin']}\t{word_dict[word]['english']}")
    
        fpleco.write(f'{pleco_make_newline()}RELATED{pleco_make_newline()}')
        related_words = sorted(set((data['chinese'])))
        for related in related_words:
            fpleco.write(f" - {pleco_make_link(related)} {word_dict[related]['pinyin']} {pleco_make_italic(word_dict[related]['english'])}{pleco_make_newline()}")

        fpleco.write('\n')

fpleco.close()

print(f'{pleco_import_file} written')
# Out:
# FoodVocabularyPleco-vi.txt written

# %%
from deep_translator import MyMemoryTranslator

text='生炒排骨'

translated = MyMemoryTranslator(source='zh-CN', target='english').translate(text)

# english = translators.translate_text(, translator='bing', from_language='zh', to_language='en')

translated
# Out:
# 'Raw Fried Spareribs'

# %%
from deep_translator import MyMemoryTranslator

text='生炒排骨'

translated = MyMemoryTranslator(source='chinese', target='english').translate(text)

# english = translators.translate_text(, translator='bing', from_language='zh', to_language='en')

translated
# Out:
# ---------------------------------------------------------------------------
# LanguageNotSupportedException             Traceback (most recent call last)
# Cell In[54], line 5
#       1 from deep_translator import MyMemoryTranslator
#       3 text='生炒排骨'
# ----> 5 translated = MyMemoryTranslator(source='chinese', target='english').translate(text)
#       7 # english = translators.translate_text(, translator='bing', from_language='zh', to_language='en')
#       9 translated
#
# File c:\Python311\env\subtitles\Lib\site-packages\deep_translator\mymemory.py:39, in MyMemoryTranslator.__init__(self, source, target, proxies, **kwargs)
#      37 self.proxies = proxies
#      38 self.email = kwargs.get("email", None)
# ---> 39 super().__init__(
#      40     base_url=BASE_URLS.get("MYMEMORY"),
#      41     source=source,
#      42     target=target,
#      43     payload_key="q",
#      44     languages=MY_MEMORY_LANGUAGES_TO_CODES,
#      45 )
#
# ...
