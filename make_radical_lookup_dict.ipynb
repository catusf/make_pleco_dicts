# %%
from tools_configs import *

# %%
wordset_freq = {}
wordset = set()

with open("wordlists/chinese_charfreq_simpl_trad.txt", "r", encoding="utf-8") as fread:
    next(fread)
    contents = fread.read()

    wordset.update(contents)

    if "\n" in wordset:
        wordset.remove("\n")

    if " " in wordset:
        wordset.remove(" ")

    wordset_freq = {word: num + 1 for num, word in enumerate(contents.split("\n"))}

def find_freq(word):
    return wordset_freq[word] if word in wordset_freq else BIGNUM


def sort_by_freq(list_chars):
    if not list_chars:
        return []

    items = sorted(
        [(word, find_freq(word)) for word in list_chars], key=lambda x: (x[1], x[0])
    )

    return [word for word, order in items]

rads = Radicals()

rads.load_radical_data()

import json
try:
    with open('char_dict.json', "r", encoding="utf-8") as fread:
        char_dict = json.load(fread)
except:
    print(f'No file {'char_dict.json'}')

print(f'{len(char_dict)=}')
wordset = set()

with open("wordlists/chinese_charfreq_simpl_trad.txt", "r", encoding="utf-8") as fread:
    next(fread)
    contents = fread.read()

    wordset.update(contents)

    if "\n" in wordset:
        wordset.remove("\n")

    if " " in wordset:
        wordset.remove(" ")

    wordset_freq = {word: num + 1 for num, word in enumerate(contents.split("\n"))}

print(f'{len(wordset_freq)=}')
exiting_word = [word for word in wordset if word in char_dict]
print(f'{len(exiting_word)=}')
# Out:
# len(char_dict)=13052
# len(wordset_freq)=12042
# len(exiting_word)=11995

# %% [markdown]
# # Count
# - No. Words by radical count
#
#     - Most popular radicals
#
# - Number and percents of words by radical count
#
# - Check words agains top freqent words (top 12k)

# %%
chars_by_rad_count = {}
chars_by_radical = {}
most_freq_radicals = {}

for word in exiting_word:
    item = char_dict[word]

    components = item['components']

    count = 0
    for comp in components:
        if rads.is_radical_variant(comp):
            count += 1

            chars_by_radical.setdefault(rads.norminal(comp), [])
            chars_by_radical[rads.norminal(comp)].append(word)

    chars_by_rad_count.setdefault(count, [])
    chars_by_rad_count[count].append(word)

count_chars_by_radical = sorted([(key, len(value)) for key, value in chars_by_radical.items()], key = lambda x: x[1], reverse=True)
count_chars_by_rad_count = sorted([(key, len(value)) for key, value in chars_by_rad_count.items()], key = lambda x: x[1], reverse=True)

print('Most freq radical count')
for num, item in enumerate(count_chars_by_rad_count):
    print(f'{item[0]}\t{item[1]}')

print('Most freq radicals')
for num, item in enumerate(count_chars_by_radical):
    print(f'{item[0]}\t{item[1]}')
    most_freq_radicals[item] = num+1
# Out:
# Most freq radical count
# 3	4268
# 2	2728
# 4	2608
# 5	1004
# 1	724
# 6	357
# 0	149
# 7	73
# 8	59
# 9	22
# 10	3
# Most freq radicals
# ⼀	2015
# ⼝	1668
# ⾋	1222
# ⼁	1151
# ⼈	1025
# ⽇	918
# ⼆	795
# ⼂	786
# ⼋	722
# ⽉	689
# ⼗	674
# ⽊	669
# ⾦	666
# ⽔	545
# ⽷	532
# ⼃	519
# ⾔	475
# ⼑	463
# ⼄	450
# ⼇	448
# ⼤	425
# ⼩	420
# ⾍	408
# ⼼	408
# ⼌	406
# ⼟	396
# ⼿	357
# ⾩	342
# ⼜	341
# ⽥	337
# ⼧	329
# ⽵	319
# ⿃	315
# ⼓	314
# ⿂	312
# ⼍	311
# ⼉	293
# ⼥	288
# ⾙	287
# ⽬	282
# ⼛	279
# ⾡	277
# ⽯	276
# ⼡	264
# ⼚	257
# ⾐	249
# ⽲	248
# ⽕	248
# ⼹	245
# ⾞	233
# ⾜	224
# ⾺	219
# ⾫	214
# ⽰	209
# ⽟	209
# ⼽	208
# ⼘	207
# ⽁	201
# ⼫	199
# ⽶	195
# ⾨	183
# ⼭	179
# ⽹	177
# ⼐	174
# ⼅	168
# ⼨	166
# ⼲	163
# ⼒	162
# ⾴	160
# ⾌	157
# ⼏	154
# ⼠	153
# ⼱	153
# ⽻	153
# ⼙	152
# ⾷	151
# ⼦	141
# ⾬	141
# ⼔	141
# ⼎	137
# ⽿	137
# ⽴	137
# ⼕	133
# ⽝	132
# ⽺	132
# ⼯	126
# ⽩	124
# ⽖	124
# ⾣	121
# ⽌	119
# ⼞	117
# ⾅	116
# ⽫	113
# ⼴	113
# ⽳	108
# ⾰	100
# ⽧	100
# ⽋	99
# ⼺	98
# ⽤	98
# ⾑	96
# ⽜	93
# ⾀	93
# ⼸	91
# ⽄	89
# ⼰	87
# ⽢	86
# ⾈	85
# ⽅	82
# ...

# %%
freq_chars_by_rad_count_stats = {}
practical_chars = set()
char_components = {}
radicals = rads.radical_list

char_set_by_radical = {}
for current in radicals:
    char_set_by_radical.setdefault(current, set())

for i in range(1, 6):
    words = chars_by_rad_count[i]
    freq_chars_by_rad_count_stats[i] = words
    practical_chars.update(words)

    for word in words:
        char_components.setdefault(word, [])

        components = char_dict[word]['components']

        for comp in components:
            if not rads.is_radical_variant(comp):
                continue

            norminal = rads.norminal(comp)
            char_set_by_radical[norminal].add(word)

            char_components[word].append(norminal)

        char_components[word].sort()
        pass
print(freq_chars_by_rad_count_stats.keys())

print(f'{count=}')
print(f'{len(practical_chars)=}')
print(f'{len(char_components)=}')
print(f'{len(char_set_by_radical)=}')
# Out:
# dict_keys([1, 2, 3, 4, 5])
# count=1
# len(practical_chars)=11332
# len(char_components)=11332
# len(char_set_by_radical)=214

# %%
from treelib import Node, Tree
import itertools


tree = Tree()

base = tree.create_node('', '')

for current in radicals:
    if current in char_set_by_radical:
        char_set = char_set_by_radical[current]

        if char_set:
            node = tree.create_node(identifier=current, tag=current, parent=base, data = char_set)

# tree.show()
# for pre, _, node in RenderTree(root):
#     print("%s%s %i" % (pre, node.name, len(node.chars)))


def add_item(components, current):
    if len(components) < 1:
        return
    
    comp = components[0]

    # print(parent)

    child_comps = current.data - char_set_by_radical[comp]

    if child_comps:
        
        child_id = current.identifier+comp
        
        node=tree.get_node(child_id)

        if not (node):
            node = tree.create_node(identifier=child_id, tag=child_id, parent=current, data=child_comps)
        
        add_item(components[1:], node)

    # tree.show()

count = 0

for word in char_components:
    components = char_components[word]
    if len(char_components[word]) < 2:
        continue
    
    # for perms in itertools.permutations(components):
    #     current = tree.get_node(perms[0])
    #     add_item(''.join(perms[1:]), current)
    current = tree.get_node(components[0])
    add_item(''.join(components[1:]), current)
    count += 1

    # if count > 500:
    #     break
    pass

tree.show()
tree_string = tree.show(stdout=False)
print(f'{len(tree.nodes)=}')
# Out:
# ├── ⼀
# │   ├── ⼀⼁
# │   │   ├── ⼀⼁⼂
# │   │   │   └── ⼀⼁⼂⼃
# │   │   │       ├── ⼀⼁⼂⼃⼝
# │   │   │       ├── ⼀⼁⼂⼃⽫
# │   │   │       ├── ⼀⼁⼂⼃⾒
# │   │   │       └── ⼀⼁⼂⼃⾦
# │   │   ├── ⼀⼁⼃
# │   │   │   ├── ⼀⼁⼃⼄
# │   │   │   │   ├── ⼀⼁⼃⼄⼿
# │   │   │   │   ├── ⼀⼁⼃⼄⽅
# │   │   │   │   ├── ⼀⼁⼃⼄⽶
# │   │   │   │   ├── ⼀⼁⼃⼄⽷
# │   │   │   │   ├── ⼀⼁⼃⼄⾡
# │   │   │   │   └── ⼀⼁⼃⼄⾩
# │   │   │   ├── ⼀⼁⼃⼆
# │   │   │   │   ├── ⼀⼁⼃⼆⼈
# │   │   │   │   ├── ⼀⼁⼃⼆⼝
# │   │   │   │   ├── ⼀⼁⼃⼆⼼
# │   │   │   │   ├── ⼀⼁⼃⼆⽇
# │   │   │   │   ├── ⼀⼁⼃⼆⽉
# │   │   │   │   ├── ⼀⼁⼃⼆⽊
# │   │   │   │   ├── ⼀⼁⼃⼆⽕
# │   │   │   │   ├── ⼀⼁⼃⼆⽧
# │   │   │   │   ├── ⼀⼁⼃⼆⽯
# │   │   │   │   ├── ⼀⼁⼃⼆⽰
# │   │   │   │   ├── ⼀⼁⼃⼆⽳
# │   │   │   │   ├── ⼀⼁⼃⼆⽵
# │   │   │   │   ├── ⼀⼁⼃⼆⾈
# │   │   │   │   ├── ⼀⼁⼃⼆⾋
# │   │   │   │   ├── ⼀⼁⼃⼆⾍
# │   │   │   │   ├── ⼀⼁⼃⼆⾔
# │   │   │   │   ├── ⼀⼁⼃⼆⾡
# │   │   │   │   ├── ⼀⼁⼃⼆⾣
# │   │   │   │   ├── ⼀⼁⼃⼆⾩
# │   │   │   │   ├── ⼀⼁⼃⼆⿂
# │   │   │   │   └── ⼀⼁⼃⼆⿒
# ...

# %%
components
# Out:
# ['⼁', '⼆', '⼋', '⽉', '⾙']

# %% [markdown]
# '├' => '＼'
# '└' => '＼'
# '─' => '⼀'
# ' ' => '　'
#
# # Alternative chars for box drawing
# ＼⼀⼀　⼀
# ｜　　　＼⼀⼀　⼀⼁
# ｜　　　｜　　　＼⼀⼀　⼀⼁⼂
# ｜　　　｜　　　｜　　　＼⼀⼀　⼀⼁⼂⼃
# ｜　　　｜　　　｜　　　　　　　＼⼀⼀　⼀⼁⼂⼃⼝
# ｜　　　｜　　　｜　　　　　　　＼⼀⼀　⼀⼁⼂⼃⽫
# ｜　　　｜　　　｜　　　　　　　＼⼀⼀　⼀⼁⼂⼃⾒
# ｜　　　｜　　　｜　　　　　　　＼⼀⼀　⼀⼁⼂⼃⾦
# ｜　　　｜　　　＼⼀⼀　⼀⼁⼃
# ｜　　　｜　　　｜　　　＼⼀⼀　⼀⼁⼃⼄
# ｜　　　｜　　　｜　　　｜　　　＼⼀⼀　⼀⼁⼃⼄⼿
# ｜　　　｜　　　｜　　　｜　　　＼⼀⼀　⼀⼁⼃⼄⽅
#
# # Originals
# ├── ⼀
# │   ├── ⼀⼁
# │   │   ├── ⼀⼁⼂
# │   │   │   └── ⼀⼁⼂⼃
# │   │   │       ├── ⼀⼁⼂⼃⼝
# │   │   │       ├── ⼀⼁⼂⼃⽫
# │   │   │       ├── ⼀⼁⼂⼃⾒
# │   │   │       └── ⼀⼁⼂⼃⾦
# │   │   ├── ⼀⼁⼃
# │   │   │   ├── ⼀⼁⼃⼄
# │   │   │   │   ├── ⼀⼁⼃⼄⼿
# │   │   │   │   ├── ⼀⼁⼃⼄⽅

# %%
def get_chars_from_rads(radicals):
    if not radicals:
        return None

    keys = list(radicals)
    lenkey = len(keys)


    char_set = char_set_by_radical[keys[0]]
    
    # print(f'{len(char_set)=}')

    for key in keys[1:]:
        char_set = char_set & char_set_by_radical[key]

        # print(f'{len(char_set)=}')

    return char_set

# Replacement for fullwidth box drawing characters 
def hex_show(char):
    return '\\u' + hex(ord(char))[2:].upper()

def replace_box_chars(tree):
    new_tree = tree
    char_map = {
        '├' : '＼',
        '└' : '＼',
        '─' : '⼀',
        ' ' : '　',
    }

    for char in char_map:
        new_tree = new_tree.replace(char, char_map[char])

    return new_tree

tree_str = '''
├── ⼀
│   ├── ⼀⼁
│   │   ├── ⼀⼁⼂
│   │   │   └── ⼀⼁⼂⼃
│   │   │       ├── ⼀⼁⼂⼃⼝
│   │   │       ├── ⼀⼁⼂⼃⽫
│   │   │       ├── ⼀⼁⼂⼃⾒'''


# print(f'[├] => [＼] {hex_show('├')} => {hex_show('＼')}')
# print(f'[└] => [＼] {hex_show('└')} => {hex_show('＼')}')
# print(f'[─] => [⼀] {hex_show('─')} => {hex_show('⼀')}')
# print(f'[ ] => [　] {hex_show(' ')} => {hex_show('　')}')

# print(f'tree: \n{tree_str}\nnew tree: \n{replace_box_chars(tree_str)}')

# %%
# # Write out page of home page of radicals
# for line in lines:
#     string = ''

#     if not line:
#         continue

#     key = regex.search(PATTERN_ZH_MUL, line).group(0)
#     if len(key) > 1:
#         continue

#     children = tree.children(key)
#     string += f'{key}\t{char_dict[key]['pinyin']}\tRadical {key}: {len(children)} branches\n'

#     for child in children:
#         string += f'{pleco_make_link(child.identifier)}'

# for line in lines:
#     if not line:
#         continue

#     key = regex.search(PATTERN_ZH_MUL, line).group(0)

#     new_line = regex.sub(PATTERN_ZH_MUL, replace_key, line)
#     print(new_line)
#     pass

# fpleco.close()

# %%
lines = tree_string.split('\n')
key_to_sorted_chars = {}

def replace_key(match_obj):
    key = match_obj.group(0)

    if key not in key_to_sorted_chars:
        chars = sort_by_freq(get_chars_from_rads(key))
        key_to_sorted_chars[key] = chars
    else:
        chars = key_to_sorted_chars[key]

    return f'{key[-1]}: {''.join(chars[:10])} {len(chars)}' 

def replace_simple_key(match_obj):
    key = match_obj.group(0)

    if key not in key_to_sorted_chars:
        chars = sort_by_freq(get_chars_from_rads(key))
        key_to_sorted_chars[key] = chars
    else:
        chars = key_to_sorted_chars[key]

    return f'{key[-1]}: {''.join(chars[:10])} {len(chars)}' 

# Build map between keys and chars at a node
for key in tree.nodes:
   
    if key not in key_to_sorted_chars:
        chars = sort_by_freq(get_chars_from_rads(key))
        key_to_sorted_chars[key] = chars
    else:
        chars = key_to_sorted_chars[key]
    pass
pass

HOME_PAGE = "偏旁"
HOME_PAGE_PY = "piānpáng"
HOME_PAGE1 = HOME_PAGE+'1'
HOME_PAGE2 = HOME_PAGE+'2'

string = ''
HOME_PAGE = "偏旁"
HOME_PAGE_PY = "piānpáng"

back_home = f"""{pleco_make_dark_gray('HOMEPAGE')} {PC_RIGHT_TRIANGLE} {pleco_make_link(HOME_PAGE)}\n"""

fpleco = open('radical_lookup_pleco.txt', 'w', encoding='utf-8')
string+=back_home

def get_rad_pinyin(rad_list):
    return ' '.join([rads.lookup(rad)['pinyin'] for rad in rad_list])

def get_rad_pinyin_abbrev(rad_list):
    return ' '.join([rads.lookup(rad)['pinyin'][0] for rad in rad_list])

MAX_SHOW = 5
WIDE_SPACE = '\u3000'

def node_to_pleco(current):
    children = sorted([x.identifier for x in tree.children(current)])
    current_chars = key_to_sorted_chars[current]
    len_current = len(current)
    
    string = ''
    
    if not current: # This is root
        key_perms = [HOME_PAGE]
        key_py_perms = [HOME_PAGE_PY]
    else:
        key_perms = [''.join(item) for item in itertools.permutations(current)]
        key_py_perms = [get_rad_pinyin(key) for key in key_perms]

    # string = f'\t{key_py}\t'

    if current:
        string += back_home

    if current_chars:
        only_these_radicals = [char for char in current_chars if len(char_components[char]) == len_current]
        count = len(only_these_radicals)
        count_str = ''

        if count > MAX_SHOW:
            count_str = f'+{count-MAX_SHOW}'

        shown_chars = [pleco_make_link(char) for char in only_these_radicals[:MAX_SHOW]]
        num_chars = pleco_make_dark_gray(f'ONLY THESE RADICALS: {len(only_these_radicals)}')

        if len(current_chars) == 1:
            string += f'{num_chars}{f'{PC_MIDDLE_DOT}'.join(shown_chars)}\n'
        else:
            string += f'{num_chars}\n{f'{PC_MIDDLE_DOT}'.join(shown_chars)} {count_str}\n'

    if children:
        string += pleco_make_dark_gray(f'BRANCHES: {len(children)}\n')

        for child in children:
            if not child:
                continue

            child_chars = key_to_sorted_chars[child]
            chil_children = sorted([x.identifier for x in tree.children(child)])

            shown_chars = [pleco_make_link(char) for char in child_chars[:MAX_SHOW]]
            if len(child_chars) == 1:
                actual_components = ''.join(char_components[child_chars[0]])
                string += f'{pleco_make_link(actual_components)}{WIDE_SPACE}{f'{PC_MIDDLE_DOT}'.join(shown_chars)}\n'
            else:
                string += f'{pleco_make_link(child)}{WIDE_SPACE}{f'{PC_MIDDLE_DOT}'.join(shown_chars)} ({len(chil_children)}/{len(child_chars)})\n'

    string = string.replace('\n', PC_NEW_LINE)
    
    for key, py in zip(key_perms, key_py_perms):
        fpleco.write(f'{key}\t{py}\t{string}\n')

    for child in children:
        if not child:
            continue

        node_to_pleco(child)

node_to_pleco('')

string = string.replace('\n', PC_NEW_LINE)
fpleco.write(f'{string}\n')

fpleco.close()

# %%
# nodes = tree.nodes

count = 0
total = set()
list_py = []
set_py = set()
abb_list_py = []
abb_set_py = set()

for key in tree.nodes:
    if not key:
       continue
    
    if len(key) < 2:
       continue
   #  if len(tree.get_node(key).data) != 1:
   #     continue
    
    py = get_rad_pinyin(key)
    list_py.append(py)
    set_py.add(py)

    abb_py = get_rad_pinyin_abbrev(key)
    abb_list_py.append(abb_py)
    abb_set_py.add(abb_py)
    
    # if py == 'yī jīn':
    #   print(key)
    #   print(tree.get_node(key).data)

print(f'{len(list_py)}')
print(f'{len(abb_set_py)}')

print(f'{len(abb_list_py)}')
print(f'{len(abb_set_py)}')
# print(f'{len(total)}')


def list_duplicates(seq):
  seen = set()
  seen_add = seen.add
  # adds all elements it doesn't know yet to seen and all other to seen_twice
  seen_twice = set( x for x in seq if x in seen or seen_add(x) )
  # turn the set into a list (as requested)
  return list( seen_twice )
dupl = list_duplicates(list_py)
print(dupl) # yields [1, 2, 5]
print(f'{len(dupl)}')

abb_dupl = list_duplicates(abb_list_py)
print(abb_dupl) # yields [1, 2, 5]
print(f'{len(abb_dupl)}')
# Out:
# 8256
# 4475
# 8256
# 4475
# ...

# %%
print('\n'.join(abb_list_py))
# Out:
# j y
# z m
# c j
# l y
# s q
# s t
# y s
# c y
# b s
# z g
# m z
# f y
# p ě
# q s
# m s
# è f
# g s
# b c
# q l
# q z
# w f
# s j
# y j
# h q
# b y
# m y
# j q
# y b
# j m
# s s
# m y
# l y
# m s
# y f
# q x
# c j
# g z
# g g
# j s
# s q
# y h
# r y
# y y
# g y
# y g
# r y
# t x
# g g
# r b
# y b
# r s
# s z
# y y
# z l
# y y
# m t
# k m
# g c
# l y
# b y
# p y
# n é
# r c
# p z
# p j
# g c
# g z
# g c
# y j
# k l
# z f
# g s
# d j
# p n
# r t
# h g
# z q
# x t
# è d
# s l
# f c
# k c
# c y
# m g
# h y
# p y
# g z
# b m
# h s
# m g
# m m
# d s
# è k
# x n
# d x
# s y
# g y
# y t
# y j
# d g
# è l
# y m
# m y
# y f
# j q
# h l
# s b
# m z
# t f
# t t
# c s
# f m
# y j
# k c
# s m
# g s
# f y
# s g
# m m
# m b
# y j
# x j
# m z
# m j
# m y
# s l
# y g
# m g
# w y
# y f
# r j
# g h
# x g
# s c
# j k
# g x
# d m
# b s
# y z
# d z
# z l
# y y
# w m
# m j
# s j
# k m
# s z
# b k
# d g
# f y
# p h
# c f
# c q
# z n
# t j
# g j
# m y
# t y
# y s
# y g
# k j
# m y
# c l
# n g
# g z
# s l
# ...

# %%
print('\n'.join(list_py))
# Out:
# jī yuè
# zhǔ mù
# chóng jiàn
# lǐ yú
# shí qīng
# sī tǔ
# yī shuǐ
# chì yè
# bīng shí
# zǐ guā
# mián zhú
# fāng yǔ
# pū ěr
# qiàn shí
# mián shuǐ
# èr fù
# gǔn shì
# bǐ chóng
# quǎn lǐ
# quǎn zì
# wǎ fù
# shé jīn
# yù jīn
# hé qí
# bāo yán
# mù yú
# jīn qiàn
# yù bái
# jīn mù
# shī shǒu
# máo yī
# lì yǔ
# mù shuǐ
# yī fù
# quǎn xué
# chì jīn
# gān zhì
# gǔ gāo
# jiōng shān
# shǒu qí
# yǎn huǒ
# rén yáng
# yǔ yán
# gōng yáng
# yuè gǔ
# rì yà
# tǔ xiǎo
# gān gǔ
# rén bǐ
# yǎn bǐ
# rì shuǐ
# shuǐ zì
# yǐ yòng
# zhú lù
# yǐn yù
# mù tián
# kǒu mù
# gān chóng
# lì yòu
# bǔ yī
# piàn yú
# nǚ ér
# rén chuò
# pū zhì
# piě jīn
# gōng cháng
# gōng zhú
# gǔn cǎo
# yī jué
# kǒu lǐ
# zǒu fù
# gōng shuǐ
# dà jīn
# pū niú
# rén tǔ
# hǎn gē
# zhōu qí
# xīn tián
# èr dà
# shuǐ lù
# fāng cǎo
# kǒu chóng
# chén yǔ
# mián gǔ
# hū yán
# pū yù
# gōng zhú
# bǐ mì
# hū shǐ
# mù gǔ
# mì má
# dāo shé
# èr kǎn
# xué niǎo
# dāo xiǎo
# shì yà
# gǔn yǐ
# yuè tián
# yáo jiàn
# dà gōng
# èr lěi
# yán mén
# mì yú
# ...

# %% [markdown]
# # Distributions of radicals
# | Len | Count | Pecentitle |
# |-----|-------|------------|
# | 0   | 149   | 1.2%       |
# | 1   | 724   | 7.3%       |
# | 2   | 2728  | 30.0%      |
# | 3   | 4268  | 65.6%      |
# | 4   | 2608  | 87.3%      |
# | 5   | 1004  | 95.7%      |
# | 6   | 357   | 98.7%      |
# | 7   | 73    | 99.3%      |
# | 8   | 59    | 99.8%      |
# | 9   | 22    | 100.0%     |
# | 10  | 3     | 100.0%     |
# | Sum | 11995 |
#
#
# So we will focus on words with 5 or less radicals, remove words without radicals
#
# # Most frequent rads
#
# | Pos | Radical | Char count | Percentitle |
# |-----|---------|------------|-------------|
# | 1   | ⼀       | 2015       | 5.3%        |
# | 2   | ⼝       | 1668       | 9.7%        |
# | 3   | ⾋       | 1222       | 13.0%       |
# | 4   | ⼁       | 1151       | 16.0%       |
# | 5   | ⼈       | 1025       | 18.7%       |
# | 6   | ⽇       | 918        | 21.2%       |
# | 7   | ⼆       | 795        | 23.3%       |
# | 8   | ⼂       | 786        | 25.4%       |
# | 9   | ⼋       | 722        | 27.3%       |
# | 10  | ⽉       | 689        | 29.1%       |
# | 11  | ⼗       | 674        | 30.9%       |
# | 12  | ⽊       | 669        | 32.6%       |
# | 13  | ⾦       | 666        | 34.4%       |
# | 14  | ⽔       | 545        | 35.8%       |
# | 15  | ⽷       | 532        | 37.3%       |
# | 16  | ⼃       | 519        | 38.6%       |
# | 17  | ⾔       | 475        | 39.9%       |
# | 18  | ⼑       | 463        | 41.1%       |
# | 19  | ⼄       | 450        | 42.3%       |
# | 20  | ⼇       | 448        | 43.5%       |
# | 21  | ⼤       | 425        | 44.6%       |
